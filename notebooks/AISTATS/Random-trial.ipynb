# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def f(c1, c2):
    return (c1 ** 2 + (c2 - 1) * c1) / (c1 ** 2 + 2 * c2 * c1 + c2 ** 2)

# %%
c1_list = range(1, 100)
c2 = 10

y_list = [f(c1, c2) for c1 in c1_list]

plt.plot(c1_list, y_list)
